# %% [markdown]
# # Shortest Paths

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/88x31.png" /></a><br />This work by <span xmlns:cc="http://creativecommons.org/ns#" property="cc:attributionName">莊宏斌</span> is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Creative Commons Attribution 4.0 International License</a>.

# %% [markdown]
# ##### Overview
#
# 在圖上選一點作為出發點，出發點與終點間的路線上不會經過同一個點和同一條邊，為一個 **Path**。
#
# 利用 **Breadth first search** 找到兩點之間的最短距離（**shortest path**）。

# %% [markdown]
# ##### Algorithm
#
# ###### Breadth first search
# 1.BFS(g,v,e)  輸入g,v,e 。g為一圖形，v為初始點，e為終點
#
# 2.level首先會記錄v點為0，reached中
#
# 3.

# %% [markdown]
# ##### Explanation
# 先選定一點作為出發點，再輸入另一點作為結束點，將出發點標記為Level=0，接著找相鄰的點，標記為Level=1。
#
# 之後依次將與Level=1相鄰的點標記為Level=2，不斷往下標記到所有點都被標記為止。

# %% [markdown]
# ##### Implementation

# %%
### The function below returns the order found by Breadth-First Search
def BFS(g, v, e):
    """
    Input:
        g: a simple graph
        v: a vertex
        e: end vertex
    Output:
        An order given by the BFS & distance of vertex v and e
    """
    level = {}      ### set level as a dictionary
    level[v] = 0    ### set level[v] as 0

    reached = [v]   ### vertices that have been found by BFS
    to_be_searched = [v]   ### vertices that have been found but we have not apply search on its neighbors

    while to_be_searched != []:
        vtx = to_be_searched.pop(0) ### set vtx as the zero-th element and remove it from the list
        extra_reached  = [i for i in g.neighbors(vtx) if i not in reached]
        l = level[vtx]
        for u in extra_reached:
            level[u]=l+1;

        reached = reached + extra_reached ### update reached
        to_be_searched = to_be_searched + extra_reached ### update to_be_searched
    print v,"和",e,"的最短距離 =",level[e];
    ###return  level[e];

# %% [markdown]
# ##### Examples

# %%
### Example 1
g = graphs.CycleGraph(7)
g.show()
BFS(g,2,6)
# Out:
# Graphics object consisting of 15 graphics primitives
# 2 和 6 的最短距離 = 3

# %%
### Example 2
g = graphs.PathGraph(5)
g.show()
BFS(g,4,1)
# Out:
# Graphics object consisting of 10 graphics primitives
# 4 和 1 的最短距離 = 3

# %%
### Example 3
g = graphs.PetersenGraph()
g.show()
BFS(g,2,3)
# Out:
# Graphics object consisting of 26 graphics primitives
# 2 和 3 的最短距離 = 1
